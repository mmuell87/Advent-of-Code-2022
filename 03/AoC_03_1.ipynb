# %%
def getvalue(a):
    abc = '-abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
    return(abc.find(a))

score = 0
with open('input.txt') as f:
    while True:
        contents= []
        line = f.readline()
        if line == '': break
        i=''
        x=0
        for x in range(int((len(line)-1)/2),len(line)-1,1): contents.append(line[x])
        for x in range(int((len(line)-1)/2)):
            if line[x] in contents:
                print(getvalue(line[x]))
                score += getvalue(line[x])
                break
            
print(str(score))
# Out:
# 33
# 45
# 17
# 28
# 14
# 39
# 3
# 33
# 30
# 40
# 19
# 13
# 10
# 29
# 38
# 16
# 7
# 26
# 34
# 14
# 45
# 43
# 45
# 13
# 4
# 12
# 18
# 29
# 20
# 43
# 33
# 19
# 23
# 23
# 45
# 2
# 52
# 26
# 40
# 8
# 19
# 4
# 28
# 13
# 16
# 23
# 17
# 13
# 18
# 43
# 4
# 45
# 43
# 49
# 32
# 26
# 45
# 36
# 19
# 44
# 40
# 6
# 45
# 52
# 34
# 45
# 28
# 20
# 42
# 14
# 33
# 3
# 39
# 43
# 46
# 8
# 18
# 28
# 48
# 8
# 23
# 4
# 7
# 40
# 36
# 34
# 16
# 22
# 4
# 26
# 46
# 14
# 34
# 4
# 22
# 42
# 10
# 52
# 3
# 10
# 38
# 20
# 34
# 8
# 4
# 17
# 23
# 8
# 48
# 40
# 6
# 17
# 26
# 22
# 52
# 10
# 46
# 42
# 6
# 20
# 6
# 13
# 28
# 23
# 16
# 17
# 38
# 44
# 40
# 2
# 16
# 26
# 44
# 46
# 36
# 49
# 3
# 45
# 3
# 2
# 46
# 20
# 12
# 36
# 42
# 18
# 49
# 45
# 36
# 33
# 4
# 34
# 10
# 14
# 38
# 43
# 3
# 2
# 4
# 48
# 40
# 38
# 8
# 6
# 10
# 16
# 18
# 48
# 30
# 17
# 43
# 34
# 17
# 42
# 36
# 8
# 39
# 16
# 43
# 18
# 7
# 20
# 28
# 3
# 7
# 16
# 26
# 12
# 10
# 36
# 38
# 22
# 19
# 36
# 13
# 23
# 46
# 45
# 28
# 7
# 48
# 32
# 38
# 2
# 3
# 8
# 17
# 39
# ...
